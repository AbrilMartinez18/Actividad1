# %% [markdown]
# <a href="https://colab.research.google.com/github/AbrilMartinez18/Actividad1/blob/main/Ciudad3_Actividad1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ACTIVIDAD 1**
# PT3. LISTINGS-BARCELONA AIRBNB
#
# ---
# **Nombre:** Abril Lizeth Martínez Salas
# --
#
# **Matricula:** A01734613

# %%
import pandas as pd
from pandas import DataFrame as df 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
barcelonaDF=pd.read_csv("listingsB.csv")

# %%
barcelonaDF.columns

# %%
barcelonaDF=barcelonaDF[['host_acceptance_rate','review_scores_rating', 'price', 'review_scores_cleanliness', 'availability_365','review_scores_communication','number_of_reviews','room_type']]

# %%
barcelonaDF.head(10)
# Out:
#   host_acceptance_rate  review_scores_rating    price  \
# 0                 100%                  4.89   $59.00
# 1                 100%                  4.83  $110.00
# 2                  97%                  4.94   $86.00
# 3                  93%                  4.38  $180.00
# 4                 100%                  4.70  $110.00
# 5                  84%                   NaN   $71.00
# 6                 100%                  4.73  $230.00
# 7                 100%                  4.34  $140.00
# 8                  99%                  4.07  $305.00
# 9                  97%                  4.52  $123.00
#
#    review_scores_cleanliness  availability_365  review_scores_communication  \
# 0                       5.00               351                         4.89
# 1                       4.70               151                         4.98
# 2                       4.94               218                         4.99
# 3                       4.72                60                         4.79
# 4                       4.90               106                         4.50
# 5                        NaN               269                          NaN
# 6                       4.88                84                         4.98
# 7                       4.42               287                         4.82
# 8                       4.44               332                         4.47
# 9                       4.75                65                         4.75
#
#    number_of_reviews        room_type
# 0                  9     Private room
# 1                 54  Entire home/apt
# 2                145  Entire home/apt
# 3                 30  Entire home/apt
# 4                 10  Entire home/apt
# 5                  0  Entire home/apt
# 6                 62  Entire home/apt
# 7                 74  Entire home/apt
# 8                 59  Entire home/apt
# 9                 48  Entire home/apt

# %%
barcelonaDF['room_type'].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Hotel room', 'Shared room'],
#       dtype=object)

# %% [markdown]
# **Ajustar formato**

# %%
barcelonaDF["host_acceptance_rate"]=barcelonaDF["host_acceptance_rate"].str.replace("%","")
barcelonaDF["price"] = barcelonaDF["price"].str.replace("$","")
barcelonaDF["price"] = barcelonaDF["price"].str.replace(",","")

# %%
barcelonaDF.head(10)
# Out:
#   host_acceptance_rate  review_scores_rating   price  \
# 0                  100                  4.89   59.00
# 1                  100                  4.83  110.00
# 2                   97                  4.94   86.00
# 3                   93                  4.38  180.00
# 4                  100                  4.70  110.00
# 5                   84                   NaN   71.00
# 6                  100                  4.73  230.00
# 7                  100                  4.34  140.00
# 8                   99                  4.07  305.00
# 9                   97                  4.52  123.00
#
#    review_scores_cleanliness  availability_365  review_scores_communication  \
# 0                       5.00               351                         4.89
# 1                       4.70               151                         4.98
# 2                       4.94               218                         4.99
# 3                       4.72                60                         4.79
# 4                       4.90               106                         4.50
# 5                        NaN               269                          NaN
# 6                       4.88                84                         4.98
# 7                       4.42               287                         4.82
# 8                       4.44               332                         4.47
# 9                       4.75                65                         4.75
#
#    number_of_reviews        room_type
# 0                  9     Private room
# 1                 54  Entire home/apt
# 2                145  Entire home/apt
# 3                 30  Entire home/apt
# 4                 10  Entire home/apt
# 5                  0  Entire home/apt
# 6                 62  Entire home/apt
# 7                 74  Entire home/apt
# 8                 59  Entire home/apt
# 9                 48  Entire home/apt

# %%
barcelonaDF.dtypes
# Out:
# host_acceptance_rate            object
# review_scores_rating           float64
# price                           object
# review_scores_cleanliness      float64
# availability_365                 int64
# review_scores_communication    float64
# number_of_reviews                int64
# room_type                       object
# dtype: object

# %% [markdown]
# **cambiar tipos de variables**

# %%
barcelonaDF['host_acceptance_rate']=barcelonaDF['host_acceptance_rate'].astype({'host_acceptance_rate': 'float64'})
barcelonaDF['price']=barcelonaDF['price'].astype({'price': 'float64'})

# %%
barcelonaDF.dtypes
# Out:
# host_acceptance_rate           float64
# review_scores_rating           float64
# price                          float64
# review_scores_cleanliness      float64
# availability_365                 int64
# review_scores_communication    float64
# number_of_reviews                int64
# room_type                       object
# dtype: object

# %%
barcelonaDF.shape
# Out:
# (16920, 8)

# %% [markdown]
# **Dividir dataframes por tipo de habitación**

# %%
#1.PRIVATE ROOM
PR=barcelonaDF[barcelonaDF['room_type']=='Private room']

#2.ENTIRE HOME/APT
FP=barcelonaDF[barcelonaDF['room_type']=='Entire home/apt']

#3 SHARED ROOM
SR=barcelonaDF[barcelonaDF['room_type']=='Shared room']

# %% [markdown]
# ##**Tipo 1. PrivateRoom**

# %%
PR=PR[['host_acceptance_rate','review_scores_rating', 'price', 'review_scores_cleanliness', 'availability_365','review_scores_communication','number_of_reviews']]

# %%
PR.head(10)
# Out:
#     host_acceptance_rate  review_scores_rating  price  \
# 0                  100.0                  4.89   59.0
# 12                  61.0                  4.78   39.0
# 16                   NaN                   NaN   36.0
# 32                  99.0                  4.97  100.0
# 33                  78.0                  4.74  200.0
# 42                 100.0                  5.00   17.0
# 47                  99.0                  4.91  100.0
# 49                 100.0                  4.90   33.0
# 57                 100.0                  4.86   43.0
# 75                  84.0                  4.74   70.0
#
#     review_scores_cleanliness  availability_365  review_scores_communication  \
# 0                        5.00               351                         4.89
# 12                       4.72               231                         4.91
# 16                        NaN               340                          NaN
# 32                       4.91                 9                         5.00
# 33                       4.30               345                         4.93
# 42                       4.50               334                         5.00
# 47                       4.96                19                         5.00
# 49                       4.50               318                         4.80
# 57                       4.85                 3                         4.92
# 75                       4.87               344                         4.88
#
#     number_of_reviews
# 0                   9
# 12                101
# 16                  0
# 32                 58
# 33                 93
# 42                  2
# 47                 56
# 49                 10
# 57                104
# 75                253

# %% [markdown]
# **Contar nulos**

# %%
valores_nulos=PR.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           2141
# review_scores_rating           1749
# price                             0
# review_scores_cleanliness      1827
# availability_365                  0
# review_scores_communication    1827
# number_of_reviews                 0
# dtype: int64

# %% [markdown]
# **Reemplazar valores**

# %%
#remplazar valores
from numpy import nan as NaN
PR=PR.fillna({'host_acceptance_rate':float(PR['host_acceptance_rate'].mean())})
PR=PR.fillna({'review_scores_rating':float(PR['review_scores_rating'].mean())})
PR=PR.fillna({'review_scores_cleanliness':float(PR['review_scores_cleanliness'].mean())})
PR=PR.fillna({'review_scores_communication':float(PR['review_scores_communication'].mean())})
valores_nulos=PR.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           0
# review_scores_rating           0
# price                          0
# review_scores_cleanliness      0
# availability_365               0
# review_scores_communication    0
# number_of_reviews              0
# dtype: int64

# %% [markdown]
# **OUTLIERS**

# %%
y=PR

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido host_acceptance_rate           121.541505
# review_scores_rating             5.334274
# price                          159.500000
# review_scores_cleanliness        5.347310
# availability_365               707.500000
# review_scores_communication      5.390073
# number_of_reviews               62.500000
# dtype: float64
# Limite inferior permitido host_acceptance_rate            64.097491
# review_scores_rating             4.042877
# price                          -44.500000
# review_scores_cleanliness        4.127817
# availability_365              -424.500000
# review_scores_communication      4.349878
# number_of_reviews              -37.500000
# dtype: float64

# %%
PR=PR[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
valores_nulos=PR.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           605
# review_scores_rating           600
# price                          732
# review_scores_cleanliness      643
# availability_365                 0
# review_scores_communication    480
# number_of_reviews              851
# dtype: int64

# %% [markdown]
# **Llenar con la media**

# %%
PR=PR.fillna({'host_acceptance_rate':float(PR['host_acceptance_rate'].mean())})
PR=PR.fillna({'review_scores_rating':float(PR['review_scores_rating'].mean())})
PR=PR.fillna({'price':float(PR['price'].mean())})
PR=PR.fillna({'review_scores_cleanliness':float(PR['review_scores_cleanliness'].mean())})
PR=PR.fillna({'review_scores_communication':float(PR['review_scores_communication'].mean())})
PR=PR.fillna({'number_of_reviews':(PR['number_of_reviews'].mean())})

# %%
valores_nulos=PR.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           0
# review_scores_rating           0
# price                          0
# review_scores_cleanliness      0
# availability_365               0
# review_scores_communication    0
# number_of_reviews              0
# dtype: int64

# %% [markdown]
# **correlaciones**

# %%
PR.corr()
# Out:
#                              host_acceptance_rate  review_scores_rating  \
# host_acceptance_rate                     1.000000             -0.015748
# review_scores_rating                    -0.015748              1.000000
# price                                    0.241800              0.021449
# review_scores_cleanliness                0.039550              0.665519
# availability_365                         0.292963             -0.064007
# review_scores_communication             -0.046802              0.659512
# number_of_reviews                        0.120518              0.043048
#
#                                 price  review_scores_cleanliness  \
# host_acceptance_rate         0.241800                   0.039550
# review_scores_rating         0.021449                   0.665519
# price                        1.000000                   0.046813
# review_scores_cleanliness    0.046813                   1.000000
# availability_365             0.138236                  -0.050410
# review_scores_communication  0.001908                   0.495401
# number_of_reviews            0.047164                   0.044245
#
#                              availability_365  review_scores_communication  \
# host_acceptance_rate                 0.292963                    -0.046802
# review_scores_rating                -0.064007                     0.659512
# price                                0.138236                     0.001908
# review_scores_cleanliness           -0.050410                     0.495401
# availability_365                     1.000000                    -0.099877
# review_scores_communication         -0.099877                     1.000000
# number_of_reviews                   -0.024027                     0.005611
#
#                              number_of_reviews
# host_acceptance_rate                  0.120518
# review_scores_rating                  0.043048
# price                                 0.047164
# review_scores_cleanliness             0.044245
# availability_365                     -0.024027
# review_scores_communication           0.005611
# number_of_reviews                     1.000000

# %%
column_sels=['host_acceptance_rate','review_scores_rating', 'price', 'review_scores_cleanliness', 'availability_365','review_scores_communication']
x=PR.loc[:,column_sels]#variables explicativas

y=PR['number_of_reviews']#target, variable dependiente

fig, axs=plt.subplots(ncols=3,nrows=2,figsize=(16,8))

axs=axs.flatten()
for i, k in enumerate(column_sels):
  sns.regplot(x=x[k],y=y,data=PR,ax=axs[i])
  plt.tight_layout(pad=0.4)

# %%
corr=PR.corrwith(PR['number_of_reviews'])
corr
# Out:
# host_acceptance_rate           0.120518
# review_scores_rating           0.043048
# price                          0.047164
# review_scores_cleanliness      0.044245
# availability_365              -0.024027
# review_scores_communication    0.005611
# number_of_reviews              1.000000
# dtype: float64

# %%
#COEFICIENTE DE DETERMINACIÓN R^2
coef_deter=pow(corr,2)
coef_deter
# Out:
# host_acceptance_rate           0.014525
# review_scores_rating           0.001853
# price                          0.002224
# review_scores_cleanliness      0.001958
# availability_365               0.000577
# review_scores_communication    0.000031
# number_of_reviews              1.000000
# dtype: float64

# %% [markdown]
# **Selección de mejor modelo de Regresión Lineal Mult. considerando el coeficiente de correlación**
#
# ---
#
# Habitación privada

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep=PR[['host_acceptance_rate','review_scores_cleanliness','review_scores_rating']]
Var_Dep= PR['number_of_reviews']

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()
type(model)
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)
# Out:
# LinearRegression()

# %%
#obtener coeficientes para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate', 'review_scores_cleanliness',
#         'review_scores_rating'], dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.19335707, 1.12991694, 2.08092879]),
#  '_residues': 1113781.345708807,
#  'rank_': 3,
#  'singular_': array([662.52477013,  21.51905666,   9.59823668]),
#  'intercept_': -23.257166704141053}

# %% [markdown]
# Ecuación
#
# ---
# Y=0.193357(host_acceptance_rate)+1.1299(review_scores_cleanliness)+2.0809(review_scores_rating)-23.257

# %% [markdown]
# **Crear el modelo matemático que describa de mejor manera el número de reseñas**

# %%
y_pred= model.predict(X=PR[['host_acceptance_rate','review_scores_cleanliness','review_scores_rating']])
y_pred
# Out:
# array([11.90386658,  9.6223611 ,  7.90322954, ...,  9.39295154,
#         8.35054617,  7.20727248])

# %%
#Coeficiente de Determinación del modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.01670896388457066

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.12926315749110673

# %% [markdown]
# ##**2.Tipo de habitación: Entire Home/Apt**

# %%
FP=FP[['host_acceptance_rate','review_scores_rating', 'price', 'review_scores_cleanliness', 'availability_365','review_scores_communication','number_of_reviews']]

# %%
FP.head(10)
# Out:
#     host_acceptance_rate  review_scores_rating  price  \
# 1                  100.0                  4.83  110.0
# 2                   97.0                  4.94   86.0
# 3                   93.0                  4.38  180.0
# 4                  100.0                  4.70  110.0
# 5                   84.0                   NaN   71.0
# 6                  100.0                  4.73  230.0
# 7                  100.0                  4.34  140.0
# 8                   99.0                  4.07  305.0
# 9                   97.0                  4.52  123.0
# 10                  98.0                  4.49  390.0
#
#     review_scores_cleanliness  availability_365  review_scores_communication  \
# 1                        4.70               151                         4.98
# 2                        4.94               218                         4.99
# 3                        4.72                60                         4.79
# 4                        4.90               106                         4.50
# 5                         NaN               269                          NaN
# 6                        4.88                84                         4.98
# 7                        4.42               287                         4.82
# 8                        4.44               332                         4.47
# 9                        4.75                65                         4.75
# 10                       4.58               144                         4.67
#
#     number_of_reviews
# 1                  54
# 2                 145
# 3                  30
# 4                  10
# 5                   0
# 6                  62
# 7                  74
# 8                  59
# 9                  48
# 10                179

# %% [markdown]
# **Contar nulos**

# %%
valores_nulos=FP.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate            367
# review_scores_rating           1780
# price                             0
# review_scores_cleanliness      1801
# availability_365                  0
# review_scores_communication    1800
# number_of_reviews                 0
# dtype: int64

# %% [markdown]
# **Reemplazar valores**

# %%
#remplazar valores
from numpy import nan as NaN
FP=FP.fillna({'host_acceptance_rate':float(FP['host_acceptance_rate'].mean())})
FP=FP.fillna({'review_scores_rating':float(FP['review_scores_rating'].mean())})
FP=FP.fillna({'review_scores_cleanliness':float(FP['review_scores_cleanliness'].mean())})
FP=FP.fillna({'review_scores_communication':float(FP['review_scores_communication'].mean())})
valores_nulos=FP.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           0
# review_scores_rating           0
# price                          0
# review_scores_cleanliness      0
# availability_365               0
# review_scores_communication    0
# number_of_reviews              0
# dtype: int64

# %% [markdown]
# **Outliers**

# %%
y=FP

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido host_acceptance_rate           116.178118
# review_scores_rating             5.350000
# price                          434.500000
# review_scores_cleanliness        5.360000
# availability_365               665.500000
# review_scores_communication      5.355000
# number_of_reviews              151.000000
# dtype: float64
# Limite inferior permitido host_acceptance_rate            73.036471
# review_scores_rating             3.910000
# price                         -113.500000
# review_scores_cleanliness        4.000000
# availability_365              -274.500000
# review_scores_communication      4.275000
# number_of_reviews              -89.000000
# dtype: float64

# %%
FP=FP[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
valores_nulos=FP.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           1208
# review_scores_rating            576
# price                           430
# review_scores_cleanliness       572
# availability_365                  0
# review_scores_communication     874
# number_of_reviews              1055
# dtype: int64

# %%
FP=FP.fillna({'host_acceptance_rate':float(FP['host_acceptance_rate'].mean())})
FP=FP.fillna({'review_scores_rating':float(FP['review_scores_rating'].mean())})
FP=FP.fillna({'price':float(FP['price'].mean())})

FP=FP.fillna({'review_scores_cleanliness':float(FP['review_scores_cleanliness'].mean())})
FP=FP.fillna({'review_scores_communication':float(FP['review_scores_communication'].mean())})
FP=FP.fillna({'number_of_reviews':(FP['number_of_reviews'].mean())})

valores_nulos=FP.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           0
# review_scores_rating           0
# price                          0
# review_scores_cleanliness      0
# availability_365               0
# review_scores_communication    0
# number_of_reviews              0
# dtype: int64

# %% [markdown]
# **correlaciones**

# %%
FP.corr()
# Out:
#                              host_acceptance_rate  review_scores_rating  \
# host_acceptance_rate                     1.000000              0.005272
# review_scores_rating                     0.005272              1.000000
# price                                    0.091320             -0.030399
# review_scores_cleanliness                0.018625              0.593051
# availability_365                         0.047952             -0.059031
# review_scores_communication              0.009355              0.573015
# number_of_reviews                        0.144971              0.011787
#
#                                 price  review_scores_cleanliness  \
# host_acceptance_rate         0.091320                   0.018625
# review_scores_rating        -0.030399                   0.593051
# price                        1.000000                   0.017351
# review_scores_cleanliness    0.017351                   1.000000
# availability_365             0.131132                  -0.034054
# review_scores_communication -0.107765                   0.430491
# number_of_reviews            0.245415                   0.055694
#
#                              availability_365  review_scores_communication  \
# host_acceptance_rate                 0.047952                     0.009355
# review_scores_rating                -0.059031                     0.573015
# price                                0.131132                    -0.107765
# review_scores_cleanliness           -0.034054                     0.430491
# availability_365                     1.000000                    -0.049900
# review_scores_communication         -0.049900                     1.000000
# number_of_reviews                    0.023797                    -0.013044
#
#                              number_of_reviews
# host_acceptance_rate                  0.144971
# review_scores_rating                  0.011787
# price                                 0.245415
# review_scores_cleanliness             0.055694
# availability_365                      0.023797
# review_scores_communication          -0.013044
# number_of_reviews                     1.000000

# %%
column_sels=['host_acceptance_rate','review_scores_rating', 'price', 'review_scores_cleanliness', 'availability_365','review_scores_communication']
x=FP.loc[:,column_sels]#variables explicativas

y=FP['number_of_reviews']#target, variable dependiente

fig, axs=plt.subplots(ncols=3,nrows=2,figsize=(16,8))

#index=0

axs=axs.flatten()
for i, k in enumerate(column_sels):
  sns.regplot(x=x[k],y=y,data=FP,ax=axs[i],color='lightblue')
  plt.tight_layout(pad=0.4)

# %%
corr=FP.corrwith(FP['number_of_reviews'])
corr
# Out:
# host_acceptance_rate           0.144971
# review_scores_rating           0.011787
# price                          0.245415
# review_scores_cleanliness      0.055694
# availability_365               0.023797
# review_scores_communication   -0.013044
# number_of_reviews              1.000000
# dtype: float64

# %%
#COEFICIENTE DE DETERMINACIÓN R^2
coef_deter=pow(corr,2)
coef_deter
# Out:
# host_acceptance_rate           0.021016
# review_scores_rating           0.000139
# price                          0.060229
# review_scores_cleanliness      0.003102
# availability_365               0.000566
# review_scores_communication    0.000170
# number_of_reviews              1.000000
# dtype: float64

# %% [markdown]
# **Selección de mejor modelo de Regresión Lineal Mult. considerando el coeficiente de correlación**
#
#
# ---
#
#
# Departamento o habitación completa

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep=FP[['host_acceptance_rate','price','review_scores_cleanliness']]
Var_Dep= FP['number_of_reviews']

from sklearn.linear_model import LinearRegression
model= LinearRegression()
type(model)
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)


#obtener coeficientes para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate', 'price', 'review_scores_cleanliness'],
#        dtype=object),
#  'n_features_in_': 3,
#  'coef_': array([0.80039342, 0.09232001, 6.95498398]),
#  '_residues': 10987438.583253121,
#  'rank_': 3,
#  'singular_': array([8724.83821178,  527.11091059,   24.48948814]),
#  'intercept_': -98.38576603819305}

# %% [markdown]
# **Crear modelo**

# %%
y_pred= model.predict(X=FP[['host_acceptance_rate','price','review_scores_cleanliness']])
y_pred
# Out:
# array([24.4972013 , 21.54953699, 25.49594771, ..., 28.84894016,
#        18.68770521, 35.03517147])

# %%
#Coeficiente de Determinación del modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.07781072940185796

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.2789457463412159

# %% [markdown]
# ##**3.Tipo de habitación: Shared Room**

# %%
SR=SR[['host_acceptance_rate','review_scores_rating', 'price', 'review_scores_cleanliness', 'availability_365','review_scores_communication','number_of_reviews']]

# %%
SR.head()
# Out:
#       host_acceptance_rate  review_scores_rating  price  \
# 1113                   NaN                  5.00  140.0
# 1172                  44.0                  0.00   25.0
# 1281                  58.0                  4.45   41.0
# 1694                  99.0                  4.69   38.0
# 1743                  99.0                  4.74   35.0
#
#       review_scores_cleanliness  availability_365  \
# 1113                       5.00                 0
# 1172                        NaN               334
# 1281                       4.61                 0
# 1694                       4.63               135
# 1743                       4.65               132
#
#       review_scores_communication  number_of_reviews
# 1113                         5.00                  4
# 1172                          NaN                  1
# 1281                         4.68                131
# 1694                         4.71                130
# 1743                         4.84                279

# %% [markdown]
# **Contar nulos**

# %%
valores_nulos=SR.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           25
# review_scores_rating           51
# price                           0
# review_scores_cleanliness      52
# availability_365                0
# review_scores_communication    52
# number_of_reviews               0
# dtype: int64

# %% [markdown]
# **Reemplazar valores**

# %%
from numpy import nan as NaN
SR=SR.fillna({'host_acceptance_rate':float(SR['host_acceptance_rate'].mean())})
SR=SR.fillna({'review_scores_rating':float(SR['review_scores_rating'].mean())})
SR=SR.fillna({'review_scores_cleanliness':float(SR['review_scores_cleanliness'].mean())})
SR=SR.fillna({'review_scores_communication':float(SR['review_scores_communication'].mean())})

valores_nulos=SR.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           0
# review_scores_rating           0
# price                          0
# review_scores_cleanliness      0
# availability_365               0
# review_scores_communication    0
# number_of_reviews              0
# dtype: int64

# %% [markdown]
# **Outliers**

# %%
y=SR

percentile25=y.quantile(0.25) #Q1
percentile75=y.quantile(0.75) #Q3
iqr= percentile75 - percentile25

Limite_Superior_iqr= percentile75 + 1.5*iqr
Limite_Inferior_iqr= percentile25 - 1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido host_acceptance_rate           119.50000
# review_scores_rating             5.06125
# price                           88.37500
# review_scores_cleanliness        4.98250
# availability_365               763.62500
# review_scores_communication      5.20375
# number_of_reviews              105.62500
# dtype: float64
# Limite inferior permitido host_acceptance_rate            67.50000
# review_scores_rating             4.05125
# price                           -0.62500
# review_scores_cleanliness        4.00250
# availability_365              -379.37500
# review_scores_communication      4.31375
# number_of_reviews              -63.37500
# dtype: float64

# %%
SR=SR[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]

# %%
valores_nulos=SR.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           21
# review_scores_rating           17
# price                          15
# review_scores_cleanliness      32
# availability_365                0
# review_scores_communication     8
# number_of_reviews              23
# dtype: int64

# %%
SR=SR.fillna({'host_acceptance_rate':float(SR['host_acceptance_rate'].mean())})
SR=SR.fillna({'review_scores_rating':float(SR['review_scores_rating'].mean())})
SR=SR.fillna({'price':float(SR['price'].mean())})

SR=SR.fillna({'review_scores_cleanliness':float(SR['review_scores_cleanliness'].mean())})
SR=SR.fillna({'review_scores_communication':float(SR['review_scores_communication'].mean())})
SR=SR.fillna({'number_of_reviews':(SR['number_of_reviews'].mean())})

valores_nulos=SR.isnull().sum()
print(valores_nulos)
# Out:
# host_acceptance_rate           0
# review_scores_rating           0
# price                          0
# review_scores_cleanliness      0
# availability_365               0
# review_scores_communication    0
# number_of_reviews              0
# dtype: int64

# %% [markdown]
# **Correlaciones**

# %%
SR.corr()
# Out:
#                              host_acceptance_rate  review_scores_rating  \
# host_acceptance_rate                     1.000000              0.118241
# review_scores_rating                     0.118241              1.000000
# price                                    0.333560              0.123938
# review_scores_cleanliness               -0.100364              0.497527
# availability_365                         0.425813             -0.026741
# review_scores_communication             -0.003764              0.597556
# number_of_reviews                       -0.288342             -0.164162
#
#                                 price  review_scores_cleanliness  \
# host_acceptance_rate         0.333560                  -0.100364
# review_scores_rating         0.123938                   0.497527
# price                        1.000000                   0.031293
# review_scores_cleanliness    0.031293                   1.000000
# availability_365             0.056651                  -0.096989
# review_scores_communication  0.156072                   0.431510
# number_of_reviews           -0.102100                   0.087063
#
#                              availability_365  review_scores_communication  \
# host_acceptance_rate                 0.425813                    -0.003764
# review_scores_rating                -0.026741                     0.597556
# price                                0.056651                     0.156072
# review_scores_cleanliness           -0.096989                     0.431510
# availability_365                     1.000000                    -0.096580
# review_scores_communication         -0.096580                     1.000000
# number_of_reviews                   -0.133140                    -0.098495
#
#                              number_of_reviews
# host_acceptance_rate                 -0.288342
# review_scores_rating                 -0.164162
# price                                -0.102100
# review_scores_cleanliness             0.087063
# availability_365                     -0.133140
# review_scores_communication          -0.098495
# number_of_reviews                     1.000000

# %%
column_sels=['host_acceptance_rate','review_scores_rating', 'price', 'review_scores_cleanliness', 'availability_365','review_scores_communication']
x=SR.loc[:,column_sels]#variables explicativas

y=SR['number_of_reviews']#target, variable dependiente

fig, axs=plt.subplots(ncols=3,nrows=2,figsize=(16,8))

#index=0

axs=axs.flatten()
for i, k in enumerate(column_sels):
  sns.regplot(x=x[k],y=y,data=SR,ax=axs[i],color='lightpink')
  plt.tight_layout(pad=0.4)

# %%
corr=SR.corrwith(SR['number_of_reviews'])
corr
# Out:
# host_acceptance_rate          -0.288342
# review_scores_rating          -0.164162
# price                         -0.102100
# review_scores_cleanliness      0.087063
# availability_365              -0.133140
# review_scores_communication   -0.098495
# number_of_reviews              1.000000
# dtype: float64

# %%
#COEFICIENTE DE DETERMINACIÓN R^2
coef_deter=pow(corr,2)
coef_deter
# Out:
# host_acceptance_rate           0.083141
# review_scores_rating           0.026949
# price                          0.010424
# review_scores_cleanliness      0.007580
# availability_365               0.017726
# review_scores_communication    0.009701
# number_of_reviews              1.000000
# dtype: float64

# %% [markdown]
# **Selección de mejor modelo de Regresión Lineal Mult. considerando el coeficiente de correlación**
# ---
# Habitación Compartida

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indep=SR[['host_acceptance_rate','review_scores_rating','price','availability_365']]
Var_Dep= SR['number_of_reviews']

from sklearn.linear_model import LinearRegression
model= LinearRegression()
type(model)
#Ajustamos el modelo con las variables antes declaradas
model.fit(X=Vars_Indep, y=Var_Dep)


#obtener coeficientes para el modelo ajustado
model.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['host_acceptance_rate', 'review_scores_rating', 'price',
#         'availability_365'], dtype=object),
#  'n_features_in_': 4,
#  'coef_': array([-7.66839409e-01, -1.53108799e+01,  6.05452701e-03, -4.07402729e-03]),
#  '_residues': 84429.46534277749,
#  'rank_': 4,
#  'singular_': array([1873.65320273,  190.7078522 ,   87.66554208,    2.64764572]),
#  'intercept_': 157.69418483029042}

# %% [markdown]
# **Crear modelo**

# %%
y_pred= model.predict(X=SR[['host_acceptance_rate','review_scores_rating','price','availability_365']])
y_pred

# %%
#Coeficiente de Determinación del modelo
coef_Deter=model.score(X=Vars_Indep, y=Var_Dep)
coef_Deter
# Out:
# 0.10082949987331713

# %%
coef_Correl=np.sqrt(coef_Deter)
coef_Correl
# Out:
# 0.31753661186281673
